# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2

get_ipytehon().run_line_
magic('matplotlib','inline')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6313a20522fb> in <module>
#       4 import cv2
#       5
# ----> 6 get_ipytehon().run_line_
#       7 magic('matplotlib','inline')
#
# NameError: name 'get_ipytehon' is not defined

# %%
img = mpimg.imread("C:/Users/User/Downloads/WhatsApp Image 2020-10-16 at 20.21.19 (1).jpeg")
print(img.shape)
# Out:
# (687, 1024, 3)

# %%
gray_img = cv2.cvtcolor(img,cv2.COLOR_RGB2GRAY)
print(gray_img.shape)
plt.inshow(gray_img, camp = "gray")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-2f09414ab058> in <module>
# ----> 1 gray_img = cv2.cvtcolor(img,cv2.COLOR_RGB2GRAY)
#       2 print(gray_img.shape)
#       3 plt.inshow(gray_img, camp = "gray")
#
# AttributeError: module 'cv2.cv2' has no attribute 'cvtcolor'

# %%
x= 181
y= 105
pix_val = gray_img[y,x]
print(pix_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6b4dc31309e7> in <module>
#       1 x= 181
#       2 y= 105
# ----> 3 pix_val = gray_img[y,x]
#       4 print(pix_val)
#
# NameError: name 'gray_img' is not defined

# %%
imgc = mpimg.imread("C:/Users/User/Downloads/WhatsApp Image 2020-10-16 at 20.21.19.jpeg")
plt.imshow(imgc)

# %%
pix_valc = imgc[y,x]
print(pix_valc)
# Out:
# [ 8 22 25]

# %%
imgcc = cv2.cvtColor(imgc,cv2.COLOR_BGR2RGB)
pix_valcC = imgcc[y,x]
print(pix_valcC)
# Out:
# [25 22  8]

# %%
image = mpimg.imread("C:/Users/User/Downloads/WhatsApp Image 2020-10-16 at 20.21.19 (1).jpeg")
print(image.shape)
print(type(image))
plt.imshow(image)
# Out:
# (687, 1024, 3)
# <class 'numpy.ndarray'>

# %%
image_copy = np.copy(image)
#mage_copy = cv2.cvtColor(image_copy,cv2.COLOR_BGR2RGB)
plt.imshow(image_copy)

# %%
green = np.array([687, 1024, 3])
mask =cv2.inRange(image_copy,green)
plt.imshow(mask , cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8ff1337949b8> in <module>
#       1 green = np.array([687, 1024, 3])
# ----> 2 mask =cv2.inRange(image_copy,green)
#       3 plt.imshow(mask , cmap="gray")
#
# TypeError: inRange() missing required argument 'upperb' (pos 3)

# %%
masked_image = np.copy(image_copy)
masked_image[mask != 0]=[0,0,0]
plt.imshow(masked_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a1136d962d3d> in <module>
#       1 masked_image = np.copy(image_copy)
# ----> 2 masked_image[mask != 0]=[0,0,0]
#       3 plt.imshow(masked_image)
#
# NameError: name 'mask' is not defined

# %%
bg_image = mpimg.imread("C:/Users/User/Downloads/WhatsApp Image 2020-10-16 at 20.21.19 (1).jpeg")
bg_img = cv2.cvtColor(bg_img,cv2.COLOR_BGR2RGB)
plt.imshow(bg_img)
crop_bg = bgimg[0:627,0:960]
crop_bg[mask == 0]=[0,0,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9d533ba18b39> in <module>
#       1 bg_image = mpimg.imread("C:/Users/User/Downloads/WhatsApp Image 2020-10-16 at 20.21.19 (1).jpeg")
# ----> 2 bg_img = cv2.cvtColor(bg_img,cv2.COLOR_BGR2RGB)
#       3 plt.imshow(bg_img)
#       4 crop_bg = bgimg[0:627,0:960]
#       5 crop_bg[mask == 0]=[0,0,0]
#
# NameError: name 'bg_img' is not defined

# %%
comp_image = crop_bg + masked  -image
pl.imshow(comp_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-2e696602e00f> in <module>
# ----> 1 comp_image = crop_bg + masked  -image
#       2 pl.imshow(comp_image)
#
# NameError: name 'crop_bg' is not defined
